# %% [markdown]
# # Initiation à Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Apply the default theme
sns.set_theme(style="darkgrid")

# %% [markdown]
# Essayons d'importer un dataset fourni par Seaborn.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="density")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Passons au cas pratique

# %% [markdown]
# Importons les données que nous avons récupérées du site Pitwall.

# %%
# %pwd
# Out:
# C:\Users\Beguier\Documents\Centrale Marseille\S9\MON 2.1

# %%
# %cd Centrale Marseille\S9\MON 2.1

# %%
position_df = pd.read_csv("Driver Position.csv", sep = ";")
position_df.head()
# Out:
#    Laps          Pilote  Position
# 0     1  Max Verstappen         1
# 1     1    Yuki Tsunoda        15
# 2     2  Max Verstappen         1
# 3     2    Yuki Tsunoda        15
# 4     3  Max Verstappen         1

# %% [markdown]
# Les données provenant du fichier .csv sont correctement importées. Nous pouvons maintenant procéder à l'affichage des graphes.

# %%
plt.figure(figsize=(10, 6))

sns.lineplot(x='Laps', y='Position', hue='Pilote', data=position_df)
sns.set(style="darkgrid", palette="husl", font_scale=1.2)
sns.despine(left=True, bottom=True) 

plt.title("Position des pilotes en fonction du numéro du tour du Grand Prix d'Abu Dhabi")
plt.xlabel('Numéro du tour')
plt.ylabel('Position')
plt.legend(title='Pilote')

# %% [markdown]
# Le résultat est plus que satisfaisant au vu du peu de lignes de code. L'utilisation de Seaborn est en plus très facile. Nous constatons cependant que le travail n'est pas terminé : l'axe des ordonnées est dans le sens inverse à la lecture traditionnelle, et les graduations en `float` laissent à désirer. Changeons tout ça !

# %%
plt.figure(figsize=(10, 6))

ax=sns.lineplot(x='Laps', y='Position', hue='Pilote', data=position_df)
sns.set(style="darkgrid", palette="husl", font_scale=1.2)
sns.despine(left=True, bottom=True) 

ax.invert_yaxis()
plt.yticks(range(1, position_df['Position'].max() + 1))

plt.title("Position des pilotes en fonction du numéro du tour du Grand Prix d'Abu Dhabi")
plt.xlabel('Numéro du tour')
plt.ylabel('Position')
plt.legend(title='Pilote')

# %% [markdown]
# Cette amélioration est satisfaisante et je préfère l'esthéthique de ce graphique par rapport à celui obtenu au MON 1.1.
#
# La dernière étape de mon MON consiste à soumettre le code que j'ai écrit à ChatGPT et de lui demander de l'améliorer, afin de voir à quelles commandes je n'ai pas pensé.

# %%
# Utiliser Seaborn pour créer les lignes directement à partir du DataFrame
plt.figure(figsize=(10, 6))
ax = sns.lineplot(x='Laps', y='Position', hue='Pilote', data=position_df, linewidth=2)

# Améliorations visuelles avec Seaborn
sns.set(style="darkgrid", palette="husl", font_scale=1.2, rc={"font.family": "Roboto"})
sns.despine(left=True, bottom=True)

# Inverser l'axe des ordonnées
ax.invert_yaxis()

# Forcer une graduation à chaque position
plt.yticks(range(1, position_df['Position'].max() + 1))

# Ajouter des titres et des légendes
plt.title("Position des pilotes en fonction du numéro du tour du Grand Prix d'Abu Dhabi")
plt.xlabel('Numéro du tour')
plt.ylabel('Position')
plt.legend(title='Pilote')
# Out:
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# findfont: Font family 'Roboto' not found.
# ...

# %% [markdown]
# La police Roboto proposée par ChatGPT n'est pas disponible, je décide donc de la remplacer par une autre.

# %%
import matplotlib.font_manager
print([f.name for f in matplotlib.font_manager.fontManager.ttflist])
# Out:
# ['cmtt10', 'cmb10', 'cmmi10', 'STIXNonUnicode', 'DejaVu Serif', 'cmr10', 'DejaVu Serif Display', 'cmex10', 'DejaVu Serif', 'DejaVu Serif', 'DejaVu Sans', 'DejaVu Sans Mono', 'cmss10', 'DejaVu Sans', 'STIXGeneral', 'DejaVu Sans Display', 'STIXSizeFourSym', 'DejaVu Sans', 'STIXSizeFiveSym', 'DejaVu Sans Mono', 'STIXNonUnicode', 'DejaVu Sans', 'STIXSizeThreeSym', 'STIXGeneral', 'STIXNonUnicode', 'STIXSizeOneSym', 'STIXSizeTwoSym', 'STIXGeneral', 'DejaVu Sans Mono', 'STIXSizeTwoSym', 'STIXGeneral', 'cmsy10', 'DejaVu Serif', 'STIXNonUnicode', 'STIXSizeThreeSym', 'STIXSizeOneSym', 'STIXSizeFourSym', 'DejaVu Sans Mono', 'Nirmala UI', 'MV Boli', 'Niagara Engraved', 'DejaVu Serif', 'Segoe Fluent Icons', 'Papyrus', 'Liberation Sans', 'Forte', 'Source Sans Pro', 'Constantia', 'DejaVu Serif', 'Rubik', 'Corbel', 'Bell MT', 'DejaVu Sans Mono', 'Bahnschrift', 'Franklin Gothic Medium', 'Old English Text MT', 'Cambria', 'Perpetua Titling MT', 'Calibri', 'Barlow Condensed', 'Liberation Sans Narrow', '
# ...

# %%
# Utiliser Seaborn pour créer les lignes directement à partir du DataFrame
plt.figure(figsize=(10, 6))
ax = sns.lineplot(x='Laps', y='Position', hue='Pilote', data=position_df, linewidth=2, palette="flare")

# Améliorations visuelles avec Seaborn
sns.set(style="darkgrid", font_scale=1.2, rc={"font.family": "Barlow Condensed"})
sns.despine(left=True, bottom=True)

# Inverser l'axe des ordonnées
ax.invert_yaxis()

# Forcer une graduation à chaque position
plt.yticks(range(1, position_df['Position'].max() + 1))

# Ajouter des titres et des légendes
plt.title("Position des pilotes en fonction du numéro du tour du Grand Prix d'Abu Dhabi")
plt.xlabel('Numéro du tour', fontdict={'family': 'Barlow Condensed'})
plt.ylabel('Position', fontdict={'family': 'Barlow Condensed'})
plt.legend(title='Pilote')

# %% [markdown]
# J'ai enfin changé la palette de couleur des courbes.
